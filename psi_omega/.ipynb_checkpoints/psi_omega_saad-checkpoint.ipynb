# %%
# 2D Lid-driven Cavity
# STREAMFUNCTION-VORTICITY FORMULATION
# Written by Mr A. J. Brierley
# Cranfield University, Bedfordshire, UK
# 03/06/2025

# %%
import numpy as np
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import cm
plt.rcParams['animation.html'] = 'html5'

# %%
nx = 32
ny = 32
lx = 1.0
ly = 1.0
dx = lx/(nx-1)
dy = ly/(ny-1)

# %%
Ut = 20.0

# %%
psi0 = np.zeros([nx,ny])
w0 = np.zeros([nx,ny])

# STREAMFUNCTION BOUNDARY CONDITIONS
psi_wall = 0.0

# VORTICITY BOUNDARY CONDITIONS 
w0[:,0] = 2.0*(psi_wall - psi0[:,1])/dx/dx                # left wall
w0[:,-1] = 2.0*(psi_wall - psi0[:,-2])/dx/dx              # right wall
w0[0,:] = 2.0*(psi_wall - psi0[1,:])/dy/dy                # bottom wall
w0[-1,:] = 2.0*(psi_wall - psi0[-2,:])/dy/dy - 2.0*Ut/dy  # top wall 

# Solution storage
psisol = []
psisol.append(psi0)
wsol = []
wsol.append(w0)

# %%
# simulation parameters
beta = 1.5
tol = 1e-4
maxIt = 30

t = 0.0  # initial time and time counter
v = 0.05  # nu
#dt = min(0.25*dx*dx/v, 4*v/Ut/Ut)
dt = 0.25*dx*dx/v
tend = 1000*dt
print('dt =', dt, 's')
print('Re =', Ut*lx/v)
# Out:
# dt = 0.005202913631633714 s
# Re = 400.0

# %%
while t < tend:
    
    #------------------------------------
    # STREAMFUNCTION-POISSON EQUATION
    #------------------------------------
    
    it = 0
    err = 1e5
    wn = wsol[-1]
    psi = psisol[-1].copy()
    while err > tol and it < maxIt:
        # psik is used for the sole purpose of calculating the error in one iteration compared to the last
        psik = np.zeros_like(psi)
        psik[1:-1, 1:-1] = psi[1:-1, 1:-1]
        for i in range(1,nx-1):
            for j in  range(1,ny-1):
                rhs = (dx*dy)**2*wn[j,i] + dy**2*(psi[j,i+1]+ psi[j,i-1]) + dx**2*(psi[j+1,i] + psi[j-1,i])
                rhs *= beta/2.0/(dx**2 + dy**2)
                psi[j,i] = rhs + (1 - beta)*psi[j,i]
        err = np.linalg.norm(psi.ravel() - psik.ravel())
        it += 1
        # print(it)
    psisol.append(psi)

    w = np.zeros_like(wn)

    #-------------------------------------
    # 2D VORTICITY TRANSPORT EQUATION
    #-------------------------------------
    
    Cx = -(psi[2:,1:-1] - psi[:-2,1:-1])/2.0/dy * (wn[1:-1,2:] - wn[1:-1,:-2])/2.0/dx
    Cy = (psi[1:-1,2:] - psi[1:-1,:-2])/2.0/dx * (wn[2:,1:-1] - wn[:-2,1:-1])/2.0/dy
    Dx = (wn[1:-1,2:] + wn[1:-1,:-2] - 2.0*wn[1:-1,1:-1])/dx/dx
    Dy = (wn[2:,1:-1] + wn[:-2,1:-1] - 2.0*wn[1:-1,1:-1])/dy/dy

    rhs = Cx + Cy + v*(Dx + Dy) 
    #rhs = v*(Dx + Dy) 
    w[1:-1,1:-1] = wn[1:-1,1:-1] + dt * rhs

    # UPDATE VORTICITY BOUNDARY CONDITIONS 
    w[:,0] = 2.0*(psi_wall - psi[:,1])/dx/dx                # left wall
    w[:,-1] = 2.0*(psi_wall - psi[:,-2])/dx/dx              # right wall
    w[0,:] = 2.0*(psi_wall - psi[1,:])/dy/dy                # bottom wall
    w[-1,:] = 2.0*(psi_wall - psi[-2,:])/dy/dy - 2.0*Ut/dy  # top wall 

    wsol.append(w)
    
    t += dt
# Out:
# /tmp/ipykernel_8337/3328160819.py:31: RuntimeWarning: overflow encountered in multiply
#   Cx = -(psi[2:,1:-1] - psi[:-2,1:-1])/2.0/dy * (wn[1:-1,2:] - wn[1:-1,:-2])/2.0/dx
# /tmp/ipykernel_8337/3328160819.py:31: RuntimeWarning: overflow encountered in divide
#   Cx = -(psi[2:,1:-1] - psi[:-2,1:-1])/2.0/dy * (wn[1:-1,2:] - wn[1:-1,:-2])/2.0/dx
# /tmp/ipykernel_8337/3328160819.py:32: RuntimeWarning: overflow encountered in multiply
#   Cy = (psi[1:-1,2:] - psi[1:-1,:-2])/2.0/dx * (wn[2:,1:-1] - wn[:-2,1:-1])/2.0/dy
# /tmp/ipykernel_8337/3328160819.py:32: RuntimeWarning: overflow encountered in divide
#   Cy = (psi[1:-1,2:] - psi[1:-1,:-2])/2.0/dx * (wn[2:,1:-1] - wn[:-2,1:-1])/2.0/dy
# /tmp/ipykernel_8337/3328160819.py:36: RuntimeWarning: overflow encountered in add
#   rhs = Cx + Cy + v*(Dx + Dy)
# /tmp/ipykernel_8337/3328160819.py:36: RuntimeWarning: invalid value encountered in add
#   rhs = Cx + Cy + v*(Dx + Dy)
# /tmp/ipykernel_8337/3328160819.py:17: RuntimeWarning: invalid value encountered in scalar add
#   rhs = (dx*dy)**2*wn[j,i] + dy**2*(psi[j,i+1]+ psi[j,i-1]) + dx**2*(psi[j+1,i] + psi[j-1,i])
# /tmp/ipykernel_8337/3328160819.py:31: RuntimeWarning: invalid value encountered in subtract
#   Cx = -(psi[2:,1:-1] - psi[:-2,1:-1])/2.0/dy * (wn[1:-1,2:] - wn[1:-1,:-2])/2.0/dx
# /tmp/ipykernel_8337/3328160819.py:32: RuntimeWarning: invalid value encountered in subtract
#   Cy = (psi[1:-1,2:] - psi[1:-1,:-2])/2.0/dx * (wn[2:,1:-1] - wn[:-2,1:-1])/2.0/dy
# /tmp/ipykernel_8337/3328160819.py:33: RuntimeWarning: invalid value encountered in add
#   Dx = (wn[1:-1,2:] + wn[1:-1,:-2] - 2.0*wn[1:-1,1:-1])/dx/dx
# /tmp/ipykernel_8337/3328160819.py:33: RuntimeWarning: invalid value encountered in subtract
#   Dx = (wn[1:-1,2:] + wn[1:-1,:-2] - 2.0*wn[1:-1,1:-1])/dx/dx
# /tmp/ipykernel_8337/3328160819.py:33: RuntimeWarning: overflow encountered in divide
#   Dx = (wn[1:-1,2:] + wn[1:-1,:-2] - 2.0*wn[1:-1,1:-1])/dx/dx
# /tmp/ipykernel_8337/3328160819.py:34: RuntimeWarning: invalid value encountered in add
#   Dy = (wn[2:,1:-1] + wn[:-2,1:-1] - 2.0*wn[1:-1,1:-1])/dy/dy
# /tmp/ipykernel_8337/3328160819.py:34: RuntimeWarning: invalid value encountered in subtract
#   Dy = (wn[2:,1:-1] + wn[:-2,1:-1] - 2.0*wn[1:-1,1:-1])/dy/dy
# /tmp/ipykernel_8337/3328160819.py:34: RuntimeWarning: overflow encountered in divide
#   Dy = (wn[2:,1:-1] + wn[:-2,1:-1] - 2.0*wn[1:-1,1:-1])/dy/dy

# %%
plt.contour(psisol[-1][:, ::-1])
plt.axis('square')
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
plt.savefig('RE400_psi.png', bbox_inches='tight')
#plt.close()

# %%
w = wsol[-1][:, ::-1]
plt.contour(w, levels=np.linspace(w.min(), w.max(), 15))

plt.axis('square')
plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
plt.savefig('RE400_vorticity.png', bbox_inches='tight')

# %%
x = np.linspace(0,1,nx)
y = np.linspace(0,1,ny)
xx,yy = np.meshgrid(x,y)
nn = 1
psi = psisol[-1]
u = (psi[2:,1:-1] - psi[:-2,1:-1])/2.0/dy
v = -(psi[1:-1, 2:] - psi[1:-1,:-2])/2.0/dx

# print(u)
# print(v)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.contourf(xx[1:-1,1:-1], yy[1:-1,1:-1], np.sqrt(u*u + v*v), levels = 100, cmap=plt.cm.jet)
ax.streamplot(xx[1:-1,1:-1],yy[1:-1,1:-1],u, v, color=abs(u*u + v*v),cmap=plt.cm.autumn, linewidth=2)
ax.set_xlim([xx[0,1],xx[0,-2]])
ax.set_aspect(1)

# %%
import pyvista as pv

data = psisol[-1]  # Extract the final 2D slice from a 3D time-series array of psisol
solx, soly = data.shape  # Ensure data is in a 2D array
# Create a uniform 2D grid in pyvista for visualising the data
grid = pv.ImageData(dimensions=(solx,soly, 1))  # (single z layer)
grid.point_data["psisol"] = data.ravel(order="F")  # Assign flattened data (Fortran style) to grid points
grid.save("psisol.vtk")

# %%
print(psisol[-1].shape)
# Out:
# (32, 32)

# %%
print(data)
# Out:
# [[ 0.  0.  0. ...  0.  0.  0.]
#  [ 0. nan nan ... nan nan  0.]
#  [ 0. nan nan ... nan nan  0.]
#  ...
#  [ 0. nan nan ... nan nan  0.]
#  [ 0. nan nan ... nan nan  0.]
#  [ 0.  0.  0. ...  0.  0.  0.]]
